# %% [markdown]
# # 2020 Data
# - We will be attempting to predict the GFSI of a country in 5 years based on certain factors.
# - Tests will be ran with 2020 Data first

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Reading Excel files for 2020
# - Testing if excel files can be read yes

# %%
gfsi_20 = pd.read_excel("2020 GFSI by country.xlsx")
main_20 = pd.read_excel("2020 main.xlsx")
display(gfsi_20)
display(main_20)
# Out:
#      Rank         Country  Score/100 (GFSI）
# 0       1         Finland              85.3
# 1       2         Ireland              83.8
# 2       3     Netherlands              79.9
# 3       4         Austria              79.4
# 4       5  Czech Republic              78.6
# ..    ...             ...               ...
# 108   109    Sierra Leone              37.0
# 109   110          Malawi              36.7
# 110   111          Zambia              36.6
# 111   112           Sudan              36.0
# 112   113           Yemen              35.7
#
# [113 rows x 3 columns]
#      Domain Code                             Domain  Area Code (M49)  \
# 0             FS  Suite of Food Security Indicators                4
# 1             FS  Suite of Food Security Indicators                4
# 2             FS  Suite of Food Security Indicators                4
# 3             FS  Suite of Food Security Indicators                4
# 4             FS  Suite of Food Security Indicators                4
# ...          ...                                ...              ...
# 1164          FS  Suite of Food Security Indicators              716
# 1165          FS  Suite of Food Security Indicators              716
# 1166          FS  Suite of Food Security Indicators              716
# 1167          FS  Suite of Food Security Indicators              716
# 1168          FS  Suite of Food Security Indicators              716
#
#              Area  Element Code Element  Item Code  \
# 0     Afghanistan          6126   Value      22013
# 1     Afghanistan          6121   Value      21035
# 2     Afghanistan          6121   Value      21034
# 3     Afghanistan          6127   Value      21030
# 4     Afghanistan          6121   Value      21047
# ...           ...           ...     ...        ...
# 1164     Zimbabwe          6121   Value      21035
# 1165     Zimbabwe          6121   Value      21034
# 1166     Zimbabwe          6127   Value      21030
# 1167     Zimbabwe          6121   Value      21047
# 1168     Zimbabwe          6121   Value      21048
#
#                                                    Item  Year Code       Year  \
# 0     Gross domestic product per capita, PPP, (const...       2020       2020
# 1     Cereal import dependency ratio (percent) (3-ye...   20192021  2019-2021
# 2     Percent of arable land equipped for irrigation...   20192021  2019-2021
# 3     Per capita food production variability (consta...       2020       2020
# 4     Percentage of population using at least basic ...       2020       2020
# ...                                                 ...        ...        ...
# 1164  Cereal import dependency ratio (percent) (3-ye...   20192021  2019-2021
# 1165  Percent of arable land equipped for irrigation...   20192021  2019-2021
# 1166  Per capita food production variability (consta...       2020       2020
# 1167  Percentage of population using at least basic ...       2020       2020
# 1168  Percentage of population using at least basic ...       2020       2020
#
#          Unit   Value Flag                         Flag Description  Note
# 0          I$  1970.6    X  Figure from international organizations   NaN
# 1           %     NaN    O                            Missing value   NaN
# 2           %     NaN    O                            Missing value   NaN
# 3     1000 I$     NaN    O                            Missing value   NaN
# 4           %    75.1    X  Figure from international organizations   NaN
# ...       ...     ...  ...                                      ...   ...
# 1164        %     NaN    O                            Missing value   NaN
# 1165        %     NaN    O                            Missing value   NaN
# 1166  1000 I$     NaN    O                            Missing value   NaN
# 1167        %    62.7    X  Figure from international organizations   NaN
# 1168        %    35.2    X  Figure from international organizations   NaN
#
# [1169 rows x 15 columns]

# %% [markdown]
# ## Filtering the data
